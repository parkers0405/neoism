# %% [markdown]
# # Neoism notebook GUI test
#
# This is **rendered Markdown** with `inline code`, a [link](https://example.com), and ~~strikethrough~~.
#
# > Cell boundaries should be visible, while this Markdown remains fully rendered.
#
# - first item
# - second item
# - [x] completed task
# - [x] open task
#
# | Feature | Expected |
# | --- | --- |
# | Markdown | Rich rendering |
# | Drag handle | Moves this whole cell |

# %% [markdown]
# ## Adjacent Markdown cell
#
# This deliberately follows another Markdown cell so their semantic boundary is easy to test.

# %%
message = "Hello from a saved notebook output!"
print(message)
print("Dragging this code cell should carry this output with it.")
# Out:
# Hello from a saved notebook output!
# Dragging this code cell should carry this output with it.

# %% [raw]
# Raw cell content: **this should not become bold**.
# It should have Raw cell chrome and no run buttons.

# %%
from math import sqrt
values = [1, 4, 9, 16, 25]
[(value, sqrt(value)) for value in values]
# Out:
# [(1, 1.0), (4, 2.0), (9, 3.0), (16, 4.0), (25, 5.0)]

# %% [markdown]
# ### Final interaction checks
#
# 1. Click each cell and check the selected-cell rail.
# 2. Drag Markdown, raw, and code cells to reorder them.
# 3. Edit this text across multiple lines and save.
# 4. Run the code cell above and verify its output remains attached.
